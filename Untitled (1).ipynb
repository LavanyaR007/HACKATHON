# %%
pip install tensorflow

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /home/u188475/.local/lib/python3.9/site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from opencv-python) (1.22.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-contrib-python as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-contrib-python in /home/u188475/.local/lib/python3.9/site-packages (4.7.0.72)
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (3.4.3)
# Requirement already satisfied: pillow>=6.2.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: numpy>=1.16 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from matplotlib) (1.22.3)
# Requirement already satisfied: python-dateutil>=2.7 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (1.22.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as td
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
img_array=cv2.imread("./Test_Dataset2/Closed_eyes/s0001_00002_0_0_0_0_0_01.png",cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_array,cmap="gray")

# %%
img_array.shape
# Out:
# (84, 84)

# %%
Datadirectory="Test_Dataset"   ##training dataset
Classes = ["Closed_eyes","Open_eyes"]    #list of classes

for category in Classes:
    path = os.path.join(Datadirectory,category)
    for img in os.listdir(path):
        img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
        backtorgb=cv2.cvtColor(img_array,cv2.COLOR_GRAY2RGB)
        plt.imshow(img_array,cmap="gray")
        plt.show()
        break
    break

# %%
img_size=224

new_array=cv2.resize(backtorgb,(img_size,img_size))
plt.imshow(new_array,cmap="gray")
plt.show()

# %% [markdown]
# reading all the images and converting them into an array for data and labels

# %%
training_Data=[]

def create_training_Data():
    for category in Classes:
        path=os.path.join(Datadirectory,category)
        class_num=Classes.index(category) #0,1
        for img in os.listdir(path):
            try:
                img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
                bactorgb=cv2.cvtColor(img_array,cv2.COLOR_GRAY2RGB)
                new_array=cv2.resize(backtorgb,(img_size,img_size))
                training_Data.append([new_array,class_num])
            except Exception as e:
                pass

# %%
create_training_Data()

# %%
print(len(training_Data))
# Out:
# 2818

# %%
import random

random.shuffle(training_Data)

# %%
x=[]
y=[]

for features,label in training_Data:
    x.append(features)
    y.append(label)

x=np.array(x).reshape(-1,img_size,img_size,3)

# %%
x.shape
# Out:
# (2818, 224, 224, 3)

# %%
#normalize the data

x=x/255.0;     ##we are normalizing it

# %%
y=np.array(y)

# %%
import pickle

pickle_out=open("x.pickle","wb")
pickle.dump(x,pickle_out)
pickle_out.close()

pickle_out=open("y.pickle","wb")
pickle.dump(y,pickle_out)
pickle_out.close()

# %%
pickle_in=open("x.pickle","rb")
x=pickle.load(pickle_in)

pickle_in=open("y.pickle","rb")
y=pickle.load(pickle_in)

# %% [markdown]
# deep learning model for traininh -Training learning

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model=tf.keras.applications.mobilenet.MobileNet()
# Out:
# 2023-03-16 02:08:15.436840: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/u188475/.local/lib/python3.9/site-packages/cv2/../../lib64:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/vpl/2023.0.0/lib:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/tbb/2021.8.0/env/../lib/intel64/gcc4.8:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/rkcommon/1.10.0/lib:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/ospray_studio/0.11.1/lib:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/ospray/2.10.0/lib:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/openvkl/1.3.1/lib:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/oidn/1.4.3/lib:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/mpi/2021.8.0//libfabric/lib:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/mpi/2021.8.0//lib/release:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/mpi/2021.8.0//lib:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/mkl/2023.0.0/lib/intel64:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/itac/2021.8.0/slib:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/ispc/1.18.1/lib/lib64:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/ipp/2021.7.0/lib/intel64:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/ippcp/2021.6.3/lib/intel64:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/ipp/2021.7.0/lib/intel64:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/embree/3.13.5/lib:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/dnnl/2023.0.0/cpu_dpcpp_gpu_dpcpp/lib:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/debugger/2023.0.0/gdb/intel64/lib:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/debugger/2023.0.0/libipt/intel64/lib:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/debugger/2023.0.0/dep/lib:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/dal/2023.0.0/lib/intel64:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/lib:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/lib/x64:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/lib/oclfpga/host/linux64/lib:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/compiler/lib/intel64_lin:/glob/development-tools/versions/oneapi/2023.0.1/oneapi/ccl/2021.8.0/lib/cpu_gpu_dpcpp
# 2023-03-16 02:08:15.436912: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-03-16 02:08:15.436957: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (s001-n079): /proc/driver/nvidia/version does not exist
# 2023-03-16 02:08:15.437880: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 112, 112, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 112, 112, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 112, 112, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 56, 56, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 56, 56, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 56, 56, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 56, 56, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 57, 57, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 28, 28, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 28, 28, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 28, 28, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 28, 28, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 29, 29, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)      2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 14, 14, 256)      1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 14, 14, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 14, 14, 512)       131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)      0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 7, 7, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 7, 7, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 7, 7, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  global_average_pooling2d (G  (None, 1, 1, 1024)       0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1, 1, 1024)        0
#
#  conv_preds (Conv2D)         (None, 1, 1, 1000)        1025000
#
#  reshape_2 (Reshape)         (None, 1000)              0
#
#  predictions (Activation)    (None, 1000)              0
#
# =================================================================
# Total params: 4,253,864
# Trainable params: 4,231,976
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
#Trasnfer learning

# %%
base_input = model.layers[0].input #input

# %%
base_output= model.layers[-4].output

# %%
Flat_layer=layers.Flatten()(base_output)
final_output=layers.Dense(1)(Flat_layer)       ##one node(1/0)
final_output=layers.Activation('sigmoid')(final_output)

# %%
new_model = keras.Model(inputs = base_input,outputs=final_output)

# %%
for layer in layers:
    layer.trainable=false
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 for layer in layers:
#       2     layer.trainable=false
#
# TypeError: 'module' object is not iterable

# %%
new_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 112, 112, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 112, 112, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 112, 112, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 56, 56, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 56, 56, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 56, 56, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 56, 56, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 57, 57, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 28, 28, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 28, 28, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 28, 28, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 28, 28, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 29, 29, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)      2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 14, 14, 256)      1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 14, 14, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 14, 14, 512)       131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)      0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 7, 7, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 7, 7, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 7, 7, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  global_average_pooling2d (G  (None, 1, 1, 1024)       0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1, 1, 1024)        0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 1)                 1025
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 3,229,889
# Trainable params: 3,208,001
# Non-trainable params: 21,888
# _________________________________________________________________

# %% [markdown]
# Settings for binary classification (open/closed)

# %%
new_model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
new_model.fit(x,y,epochs=1,validation_split=0.1)      ##training
# Out:
# 80/80 [==============================] - 86s 995ms/step - loss: 0.7502 - accuracy: 0.5083 - val_loss: 1.0317 - val_accuracy: 0.4752

# %%
new_model.save('my_model.h5')

# %%
new_model=tf.keras.models.load_model('my_model.h5')

# %% [markdown]
# checking the network for predictions

# %%
img_array=cv2.imread('./Test_Dataset/Open_eyes/s0001_01842_0_0_1_0_0_01.png',cv2.IMREAD_GRAYSCALE)
backtorgb=cv2.cvtColor(img_array,cv2.COLOR_GRAY2RGB)
new_array=cv2.resize(backtorgb,(img_size,img_size))

# %%
x_input = np.array(new_array).reshape(1,img_size,img_size,3)

# %%
x_input.shape
# Out:
# (1, 224, 224, 3)

# %%
plt.imshow(new_array)

# %%
x_input=x_input/255.0

# %%
prediction=new_model.predict(x_input)
# Out:
# 1/1 [==============================] - 0s 370ms/step

# %%
prediction
# Out:
# array([[0.06760207]], dtype=float32)

# %%
#for closed eyes
img_array=cv2.imread('./Test_Dataset/Closed_eyes/s0001_00002_0_0_0_0_0_01.png',cv2.IMREAD_GRAYSCALE)
backtorgb=cv2.cvtColor(img_array,cv2.COLOR_GRAY2RGB)
new_array=cv2.resize(backtorgb,(img_size,img_size))

# %%
x_input = np.array(new_array).reshape(1,img_size,img_size,3)

# %%
x_input.shape
# Out:
# (1, 224, 224, 3)

# %%
plt.imshow(new_array)

# %%
x_input=x_input/255.0

# %%
prediction=new_model.predict(x_input)
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %%
prediction
# Out:
# array([[0.10113535]], dtype=float32)

# %% [markdown]
# Lets check on unknown images

# %%
img=cv2.imread('test5.jfif')

#img=cv2.imread('test6.jfif')

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
eye_cascade=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_eye.xml')

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
eyes=eye_cascade.detectMultiScale(gray,1.1,4)

# %%
for(x,y,w,h) in eyes:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# Croping the eye image

# %%
eye_cascade=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_eye.xml')
gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#print(faceCascade.empty())

eyes=eye_cascade.detectMultiScale(gray,1.1,4)
for x,y,w,h in eyes:
    roi_gray=gray[y:y+h,x:x+w]
    roi_color=img[y:y+h,x:x+w]
    eyess=eye_cascade.detectMultiScale(roi_gray)
    if len(eyess)==0:
        print("eyes are not detected")
    else:
        for(ex,ey,ew,eh) in eyess:
            eyes_roi=roi_color[ey:ey+eh,ex:ex+ew]

# %%
plt.imshow(cv2.cvtColor(eyes_roi,cv2.COLOR_BGR2RGB))

# %%
eyes_roi.shape
# Out:
# (45, 45, 3)

# %%
final_image=cv2.resize(eyes_roi,(224,224))
final_image=np.expand_dims(final_image,axis=0) #nees fourth dimension
final_image=final_image/255.0

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
new_model.predict(final_image)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# array([[0.0523567]], dtype=float32)

# %% [markdown]
# Realtime Video Demo

# %% [markdown]
# First detect that eyes are closed or open

# %%
import cv2

path="haarcascade_frontalface_default.xml"
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

cap=cv2.VideoCapture(1)
cap.set(3,640) # adjust width
cap.set(4,480) # adjust height
#check if the webcam is opned correctly

if not cap.isOpened():
    cap=cv2.VideoCapture(0)
    
if not cap.isOpened():
    raise IOError("Cannot open webcam")
    
    
while True:
    ret,frame=cap.read()
    eye_cascade=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_eye.xml')
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
    
    eyes=eye_cascade.detectMultiScale(gray,1,1,4)
    for x,y,w,h in eyes:
        roi_gray=gray[y:y+h,x:x+w]
        roi_color=frame[y:y+h,x:x+w]
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)
        eyess=eye_cascade.dtectMultiScale(roi_gray)
        if len(eyess)==0:
            print("eyes are not detected")
        else:
            for (ex,ey,ew,eh) in eyes:
                eyes_roi=roi_color[ey:ey+eh,ex:ex+ew]
    
    
    final_image=cv2.resize(eyes_roi,(224,224))
    final_image=np.expand_dims(final_image,axis=0)    #need fourth dimension
    final_image=final_image/255.0
    
    Prediction=new_model.predict(final_image)
    if(Predictions>0):
        status="Open Eyes"
    else:
        status="Closed Eyes"

    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    print(faceCascade.empty())
    faces=faceCascade.detectMultiScale(gray,1.1,4)
    
    #draw a rectangle around the faces
    
    for(x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)
        
    font = cv2.FONT_HERSHEY_SIMPLEX
    
    #Use putText() method for inserting text on video
    
    cv2.putText(frame,status,(50,50),font,3,(0,0,255),2,cv2.LINE_4)
    cv2.imshow('Drowsiness Detection Tutorial',frame)
    
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /home/u188475/.local/lib/python3.9/site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from opencv-python) (1.22.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-contrib-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-contrib-python
#   Using cached opencv_contrib_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67.9 MB)
# Requirement already satisfied: numpy>=1.17.3 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from opencv-contrib-python) (1.22.3)
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.7.0.72
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install deepface
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting deepface
#   Downloading deepface-0.0.79-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 123.1 kB/s eta 0:00:00a 0:00:01
# Collecting gdown>=3.10.1
#   Downloading gdown-4.6.4-py3-none-any.whl (14 kB)
# Collecting fire>=0.4.0
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 245.4 kB/s eta 0:00:00 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting mtcnn>=0.1.0
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 2.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: opencv-python>=4.5.5.64 in /home/u188475/.local/lib/python3.9/site-packages (from deepface) (4.7.0.72)
# Requirement already satisfied: numpy>=1.14.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from deepface) (1.22.3)
# Requirement already satisfied: Flask>=1.1.2 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from deepface) (1.1.2)
# Requirement already satisfied: tensorflow>=1.9.0 in /home/u188475/.local/lib/python3.9/site-packages (from deepface) (2.11.0)
# Collecting gunicorn>=20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 181.7 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: Pillow>=5.2.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from deepface) (9.3.0)
# Requirement already satisfied: tqdm>=4.30.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from deepface) (4.64.0)
# Requirement already satisfied: keras>=2.2.0 in /home/u188475/.local/lib/python3.9/site-packages (from deepface) (2.11.0)
# Requirement already satisfied: pandas>=0.23.4 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from deepface) (1.5.1)
# Collecting retina-face>=0.0.1
#   Downloading retina_face-0.0.13-py3-none-any.whl (16 kB)
# Requirement already satisfied: six in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: termcolor in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from fire>=0.4.0->deepface) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from Flask>=1.1.2->deepface) (2.0.2)
# Requirement already satisfied: Jinja2>=2.10.1 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from Flask>=1.1.2->deepface) (3.0.3)
# Requirement already satisfied: click>=5.1 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from Flask>=1.1.2->deepface) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from Flask>=1.1.2->deepface) (2.0.1)
# Requirement already satisfied: requests[socks] in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from gdown>=3.10.1->deepface) (2.28.1)
# Collecting filelock
#   Downloading filelock-3.10.0-py3-none-any.whl (9.9 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.11.2-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 427.3 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: setuptools>=3.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from gunicorn>=20.1.0->deepface) (63.4.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from pandas>=0.23.4->deepface) (2022.1)
# Requirement already satisfied: wrapt>=1.11.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (1.13.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (1.42.0)
# Requirement already satisfied: absl-py>=1.0.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (1.3.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /home/u188475/.local/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (2.11.2)
# Requirement already satisfied: google-pasta>=0.1.1 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/u188475/.local/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (3.19.6)
# Requirement already satisfied: flatbuffers>=2.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (2.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /home/u188475/.local/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (2.11.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (4.1.1)
# Requirement already satisfied: astunparse>=1.6.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (3.6.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/u188475/.local/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (15.0.6.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/u188475/.local/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: packaging in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (21.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.37.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from Jinja2>=2.10.1->Flask>=1.1.2->deepface) (2.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow>=1.9.0->deepface) (1.33.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow>=1.9.0->deepface) (0.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow>=1.9.0->deepface) (1.6.0)
# Requirement already satisfied: markdown>=2.6.8 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow>=1.9.0->deepface) (3.3.4)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.4-py3-none-any.whl (37 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from packaging->tensorflow>=1.9.0->deepface) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=1.9.0->deepface) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=1.9.0->deepface) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=1.9.0->deepface) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/tensorflow/2.10.0.0/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=1.9.0->deepface) (3.2.0)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116933 sha256=f07af737c04bf7f746f24a46ef34f60af4da4defef144040c1736e53d8815513
#   Stored in directory: /home/u188475/.cache/pip/wheels/f7/f1/89/b9ea2bf8f80ec027a88fef1d354b3816b4d3d29530988972f6
# Successfully built fire
# Installing collected packages: soupsieve, gunicorn, fire, filelock, mtcnn, beautifulsoup4, gdown, retina-face, deepface
# Successfully installed beautifulsoup4-4.11.2 deepface-0.0.79 filelock-3.10.0 fire-0.5.0 gdown-4.6.4 gunicorn-20.1.0 mtcnn-0.1.1 retina-face-0.0.13 soupsieve-2.4
# Note: you may need to restart the kernel to use updated packages.
